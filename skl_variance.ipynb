# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Define ranges for x and y
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)

# Compute z
Z = np.log(X / (0.8 * X + 0.2 * Y)) + 1 - 0.8 * (X / (0.8 * X + 0.2 * Y))

# Plotting
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D plot of z = log(x / (0.8x + 0.2y)) + 1 - 0.8 * (x / (0.8x + 0.2y))')

plt.tight_layout()
plt.show()


# Create a contour plot of the same function
fig, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(X, Y, Z, levels=50, cmap='viridis')
cbar = plt.colorbar(contour)
cbar.set_label('z value')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Contour plot of z = log(x / (0.8x + 0.2y)) + 1 - 0.8 * (x / (0.8x + 0.2y))')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2100332/3880449304.py:7: RuntimeWarning: invalid value encountered in divide
#   Z = np.log(X / (0.8 * X + 0.2 * Y)) + 1 - 0.8 * (X / (0.8 * X + 0.2 * Y))
# /tmp/ipykernel_2100332/3880449304.py:7: RuntimeWarning: divide by zero encountered in log
#   Z = np.log(X / (0.8 * X + 0.2 * Y)) + 1 - 0.8 * (X / (0.8 * X + 0.2 * Y))

# %%
# Define ranges for x and y
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)

alpha = 0.8

# Compute z
Z = np.log(X / (alpha * X + (1-alpha) * Y)) + 1 - alpha * (X / (alpha * X + (1-alpha) * Y))

# Plotting
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D plot of z = log(x / (0.8x + 0.2y)) + 1 - 0.8 * (x / (0.8x + 0.2y))')

plt.tight_layout()
plt.show()

# Create a contour plot of the same function
fig, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(X, Y, Z, levels=50, cmap='viridis')
cbar = plt.colorbar(contour)
cbar.set_label('z value')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Contour plot of z = log(x / (0.5x + 0.5y)) + 1 - 0.5 * (x / (0.5x + 0.5y))')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2561216/2220328624.py:9: RuntimeWarning: invalid value encountered in divide
#   Z = np.log(X / (alpha * X + (1-alpha) * Y)) + 1 - alpha * (X / (alpha * X + (1-alpha) * Y))
# /tmp/ipykernel_2561216/2220328624.py:9: RuntimeWarning: divide by zero encountered in log
#   Z = np.log(X / (alpha * X + (1-alpha) * Y)) + 1 - alpha * (X / (alpha * X + (1-alpha) * Y))

# %%
# Define ranges for x and y
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)

# Compute z
Z = np.log(X / Y)

# Plotting
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D plot of z = log(x / y)')

plt.tight_layout()
plt.show()


# Create a contour plot of the same function
fig, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(X, Y, Z, levels=50, cmap='viridis')
cbar = plt.colorbar(contour)
cbar.set_label('z value')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Contour plot of z = log(x / y)')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2100332/1353245713.py:7: RuntimeWarning: divide by zero encountered in divide
#   Z = np.log(X / Y)
# /tmp/ipykernel_2100332/1353245713.py:7: RuntimeWarning: invalid value encountered in divide
#   Z = np.log(X / Y)
# /tmp/ipykernel_2100332/1353245713.py:7: RuntimeWarning: divide by zero encountered in log
#   Z = np.log(X / Y)

# %%
# Define ranges for x and y
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)

alpha = 0.4

# Compute z
Z = (alpha*X + (1-alpha) * Y) / (X) - 1 -np.log((alpha*X + (1-alpha) * Y) / X)

# # Plotting
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, Y, Z, cmap='viridis')
# ax.set_xlabel('x')
# ax.set_ylabel('y')
# ax.set_zlabel('z')
# ax.set_title('3D plot of z = log(x / y)')

# plt.tight_layout()
# plt.show()


# Create a contour plot of the same function
fig, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(X, Y, Z, levels=50, cmap='viridis')
cbar = plt.colorbar(contour)
cbar.set_label('z value')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Contour plot of z = log(x / y)')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2561216/3601513015.py:9: RuntimeWarning: divide by zero encountered in divide
#   Z = (alpha*X + (1-alpha) * Y) / (X) - 1 -np.log((alpha*X + (1-alpha) * Y) / X)
# /tmp/ipykernel_2561216/3601513015.py:9: RuntimeWarning: invalid value encountered in divide
#   Z = (alpha*X + (1-alpha) * Y) / (X) - 1 -np.log((alpha*X + (1-alpha) * Y) / X)
# /tmp/ipykernel_2561216/3601513015.py:9: RuntimeWarning: invalid value encountered in subtract
#   Z = (alpha*X + (1-alpha) * Y) / (X) - 1 -np.log((alpha*X + (1-alpha) * Y) / X)

# %%
# Define ranges for x and y
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)

alpha = 0.8

# John Schulman skl的gradient 图

# Compute z
Z = np.log(X / (alpha * X + (1-alpha) * Y)) + 1 - alpha * (X / (alpha * X + (1-alpha) * Y)) - 1 + alpha

# Z = np.log(X / Y)

# Plotting
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, Y, Z, cmap='viridis')
# ax.set_xlabel('x')
# ax.set_ylabel('y')
# ax.set_zlabel('z')
# ax.set_title('3D plot of z = log(x / (0.8x + 0.2y)) + 1 - 0.8 * (x / (0.8x + 0.2y))')

# plt.tight_layout()
# plt.show()

# Create a contour plot of the same function
fig, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(X, Y, Z, levels=50, cmap='viridis')
cbar = plt.colorbar(contour)
cbar.set_label('z value')

ax.set_xlabel('pi')
ax.set_ylabel('pi_ref')
ax.set_title('Contour plot of z = log(x / (0.5x + 0.5y)) + 1 - 0.5 * (x / (0.5x + 0.5y))')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2585163/2047216811.py:11: RuntimeWarning: invalid value encountered in divide
#   Z = np.log(X / (alpha * X + (1-alpha) * Y)) + 1 - alpha * (X / (alpha * X + (1-alpha) * Y)) - 1 + alpha
# /tmp/ipykernel_2585163/2047216811.py:11: RuntimeWarning: divide by zero encountered in log
#   Z = np.log(X / (alpha * X + (1-alpha) * Y)) + 1 - alpha * (X / (alpha * X + (1-alpha) * Y)) - 1 + alpha

# %%
# Define ranges for x and y
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)

alpha = 0.9

# Compute z
Z = (Y/X) - 1 - np.log((Y) / X)
# Z = np.log((X) / (Y))

# # Plotting
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, Y, Z, cmap='viridis')
# ax.set_xlabel('x')
# ax.set_ylabel('y')
# ax.set_zlabel('z')
# ax.set_title('3D plot of z = log(x / y)')

# plt.tight_layout()
# plt.show()


# Create a contour plot of the same function
fig, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(X, Y, Z, levels=50, cmap='viridis')
cbar = plt.colorbar(contour)
cbar.set_label('z value')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Contour plot of z = log(x / y)')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2561216/3574775216.py:9: RuntimeWarning: divide by zero encountered in divide
#   Z = (Y/X) - 1 - np.log((Y) / X)
# /tmp/ipykernel_2561216/3574775216.py:9: RuntimeWarning: invalid value encountered in divide
#   Z = (Y/X) - 1 - np.log((Y) / X)
# /tmp/ipykernel_2561216/3574775216.py:9: RuntimeWarning: divide by zero encountered in log
#   Z = (Y/X) - 1 - np.log((Y) / X)
# /tmp/ipykernel_2561216/3574775216.py:9: RuntimeWarning: invalid value encountered in subtract
#   Z = (Y/X) - 1 - np.log((Y) / X)
